# %% [markdown]
# # Google Data Analytics Capstone Project (Cyclistic bike-share analysis)

# %% [markdown]
# We will be using jupyter notebook for the prepare, process, and analyze phrase, then we will be using Tableau for additional analysis and share phrase

# %% [markdown]
# ## Prepare

# %%
# Import all the library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from geopy.distance import geodesic
import seaborn as sns
import plotly.express as px
pd.set_option('display.max_columns', None)

# %%
# Define the path to the files
path = r'C:\Users\USER\Data\2023-divvy-tripdata\\'

# List of filenames for each month
filenames = [
    '202301-divvy-tripdata.csv',
    '202302-divvy-tripdata.csv',
    '202303-divvy-tripdata.csv',
    '202304-divvy-tripdata.csv',
    '202305-divvy-tripdata.csv',
    '202306-divvy-tripdata.csv',
    '202307-divvy-tripdata.csv',
    '202308-divvy-tripdata.csv',
    '202309-divvy-tripdata.csv',
    '202310-divvy-tripdata.csv',
    '202311-divvy-tripdata.csv',
    '202312-divvy-tripdata.csv'
]

# Create an empty list to hold the DataFrames
data_frames = []

# Loop through the filenames and read each file into a DataFrame
for filename in filenames:
    file_path = path + filename
    df = pd.read_csv(file_path)
    data_frames.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(data_frames, ignore_index=True)

combined_df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        F96D5A74A3E41399  electric_bike  2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike  2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike  2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike  2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike  2023-01-12 13:58:01
# ...                   ...            ...                  ...
# 5719872  F74DF9549B504A6B  electric_bike  2023-12-07 13:15:24
# 5719873  BCDA66E761CC1029   classic_bike  2023-12-08 18:42:21
# 5719874  D2CF330F9C266683   classic_bike  2023-12-05 14:09:11
# 5719875  3829A0D1E00EE970  electric_bike  2023-12-02 21:36:07
# 5719876  A373F5B447AEA508   classic_bike  2023-12-11 13:07:46
#
#                     ended_at           start_station_name start_station_id  \
# 0        2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2        2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3        2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4        2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                      ...                          ...              ...
# 5719872  2023-12-07 13:17:37            900 W Harrison St            13028
# 5719873  2023-12-08 18:45:56            900 W Harrison St            13028
# 5719874  2023-12-05 14:13:01            900 W Harrison St            13028
# 5719875  2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 5719876  2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 5719872      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 5719873      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 5719874      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 5719875            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 5719876      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual
# 0        41.930000 -87.640000        member
# 1        41.809835 -87.599383        member
# 2        42.039742 -87.699413        casual
# 3        41.809835 -87.599383        member
# 4        41.809835 -87.599383        member
# ...            ...        ...           ...
# 5719872  41.874640 -87.657030        casual
# 5719873  41.874640 -87.657030        casual
# 5719874  41.874640 -87.657030        member
# 5719875  41.885492 -87.652289        casual
# 5719876  41.874640 -87.657030        member
#
# [5719877 rows x 13 columns]

# %% [markdown]
# ## Process

# %%
# Inspect the data type
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5719877 entries, 0 to 5719876
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 567.3+ MB

# %%
# See if there are any missing values
combined_df.isnull().sum()
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    875716
# start_station_id      875848
# end_station_name      929202
# end_station_id        929343
# start_lat                  0
# start_lng                  0
# end_lat                 6990
# end_lng                 6990
# member_casual              0
# dtype: int64

# %%
# See if there are any duplicate
combined_df.duplicated().sum()
# Out:
# 0

# %%
# Remove all rows that contain missing values and reset the index
cleaned_df = combined_df.dropna().reset_index(drop=True)
cleaned_df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        F96D5A74A3E41399  electric_bike  2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike  2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike  2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike  2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike  2023-01-12 13:58:01
# ...                   ...            ...                  ...
# 4331702  F74DF9549B504A6B  electric_bike  2023-12-07 13:15:24
# 4331703  BCDA66E761CC1029   classic_bike  2023-12-08 18:42:21
# 4331704  D2CF330F9C266683   classic_bike  2023-12-05 14:09:11
# 4331705  3829A0D1E00EE970  electric_bike  2023-12-02 21:36:07
# 4331706  A373F5B447AEA508   classic_bike  2023-12-11 13:07:46
#
#                     ended_at           start_station_name start_station_id  \
# 0        2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2        2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3        2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4        2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                      ...                          ...              ...
# 4331702  2023-12-07 13:17:37            900 W Harrison St            13028
# 4331703  2023-12-08 18:45:56            900 W Harrison St            13028
# 4331704  2023-12-05 14:13:01            900 W Harrison St            13028
# 4331705  2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4331706  2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4331702      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4331703      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331704      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331705            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4331706      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual
# 0        41.930000 -87.640000        member
# 1        41.809835 -87.599383        member
# 2        42.039742 -87.699413        casual
# 3        41.809835 -87.599383        member
# 4        41.809835 -87.599383        member
# ...            ...        ...           ...
# 4331702  41.874640 -87.657030        casual
# 4331703  41.874640 -87.657030        casual
# 4331704  41.874640 -87.657030        member
# 4331705  41.885492 -87.652289        casual
# 4331706  41.874640 -87.657030        member
#
# [4331707 rows x 13 columns]

# %%
# Change the datatype of started_at and ended_at to datetime
cleaned_df['started_at'] = pd.to_datetime(cleaned_df['started_at'])
cleaned_df['ended_at'] = pd.to_datetime(cleaned_df['ended_at'])
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4331707 entries, 0 to 4331706
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 429.6+ MB

# %%
# We will calculate the duration of each ride by using started_at and ended_at and name it ride_duration_seconds
cleaned_df['ride_duration_seconds'] = (cleaned_df['ended_at'] - cleaned_df['started_at']).dt.total_seconds()
cleaned_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42 2023-01-21 20:16:33
# 1  13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36 2023-01-10 15:46:05
# 2  BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57 2023-01-02 08:05:11
# 3  C90792D034FED968   classic_bike 2023-01-22 10:52:58 2023-01-22 11:01:44
# 4  3397017529188E8A   classic_bike 2023-01-12 13:58:01 2023-01-12 14:13:20
#
#             start_station_name start_station_id  \
# 0  Lincoln Ave & Fullerton Ave     TA1309000058
# 1        Kimbark Ave & 53rd St     TA1309000037
# 2       Western Ave & Lunt Ave           RP-005
# 3        Kimbark Ave & 53rd St     TA1309000037
# 4        Kimbark Ave & 53rd St     TA1309000037
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0       Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2  Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4         Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
#
#      end_lat    end_lng member_casual  ride_duration_seconds
# 0  41.930000 -87.640000        member                  651.0
# 1  41.809835 -87.599383        member                  509.0
# 2  42.039742 -87.699413        casual                  794.0
# 3  41.809835 -87.599383        member                  526.0
# 4  41.809835 -87.599383        member                  919.0

# %%
# We will create another column using ride_duration_seconds but format it from second to HHMMSS 
cleaned_df['ride_duration'] = cleaned_df['ride_duration_seconds'].apply(lambda x: f"{int(x//3600):02}:{int((x%3600)//60):02}:{int(x%60):02}")
cleaned_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike 2023-01-12 13:58:01
# ...                   ...            ...                 ...
# 4331702  F74DF9549B504A6B  electric_bike 2023-12-07 13:15:24
# 4331703  BCDA66E761CC1029   classic_bike 2023-12-08 18:42:21
# 4331704  D2CF330F9C266683   classic_bike 2023-12-05 14:09:11
# 4331705  3829A0D1E00EE970  electric_bike 2023-12-02 21:36:07
# 4331706  A373F5B447AEA508   classic_bike 2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2       2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3       2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4       2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                     ...                          ...              ...
# 4331702 2023-12-07 13:17:37            900 W Harrison St            13028
# 4331703 2023-12-08 18:45:56            900 W Harrison St            13028
# 4331704 2023-12-05 14:13:01            900 W Harrison St            13028
# 4331705 2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4331706 2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4331702      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4331703      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331704      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331705            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4331706      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual  ride_duration_seconds  \
# 0        41.930000 -87.640000        member                  651.0
# 1        41.809835 -87.599383        member                  509.0
# 2        42.039742 -87.699413        casual                  794.0
# 3        41.809835 -87.599383        member                  526.0
# 4        41.809835 -87.599383        member                  919.0
# ...            ...        ...           ...                    ...
# 4331702  41.874640 -87.657030        casual                  133.0
# 4331703  41.874640 -87.657030        casual                  215.0
# 4331704  41.874640 -87.657030        member                  230.0
# 4331705  41.885492 -87.652289        casual                 1058.0
# 4331706  41.874640 -87.657030        member                  218.0
#
#         ride_duration
# 0            00:10:51
# 1            00:08:29
# 2            00:13:14
# 3            00:08:46
# 4            00:15:19
# ...               ...
# 4331702      00:02:13
# 4331703      00:03:35
# 4331704      00:03:50
# 4331705      00:17:38
# 4331706      00:03:38
#
# [4331707 rows x 15 columns]

# %%
# Next we will calculate the distance of each ride
def calculate_distance(row):
    start_coords = (row['start_lat'], row['start_lng'])
    end_coords = (row['end_lat'], row['end_lng'])
    return geodesic(start_coords, end_coords).km

cleaned_df['ride_distance_km'] = cleaned_df.apply(calculate_distance, axis=1)

# %%
cleaned_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike 2023-01-12 13:58:01
# ...                   ...            ...                 ...
# 4331702  F74DF9549B504A6B  electric_bike 2023-12-07 13:15:24
# 4331703  BCDA66E761CC1029   classic_bike 2023-12-08 18:42:21
# 4331704  D2CF330F9C266683   classic_bike 2023-12-05 14:09:11
# 4331705  3829A0D1E00EE970  electric_bike 2023-12-02 21:36:07
# 4331706  A373F5B447AEA508   classic_bike 2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2       2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3       2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4       2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                     ...                          ...              ...
# 4331702 2023-12-07 13:17:37            900 W Harrison St            13028
# 4331703 2023-12-08 18:45:56            900 W Harrison St            13028
# 4331704 2023-12-05 14:13:01            900 W Harrison St            13028
# 4331705 2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4331706 2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4331702      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4331703      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331704      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331705            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4331706      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual  ride_duration_seconds  \
# 0        41.930000 -87.640000        member                  651.0
# 1        41.809835 -87.599383        member                  509.0
# 2        42.039742 -87.699413        casual                  794.0
# 3        41.809835 -87.599383        member                  526.0
# 4        41.809835 -87.599383        member                  919.0
# ...            ...        ...           ...                    ...
# 4331702  41.874640 -87.657030        casual                  133.0
# 4331703  41.874640 -87.657030        casual                  215.0
# 4331704  41.874640 -87.657030        member                  230.0
# 4331705  41.885492 -87.652289        casual                 1058.0
# 4331706  41.874640 -87.657030        member                  218.0
#
#         ride_duration  ride_distance_km
# 0            00:10:51          0.839313
# 1            00:08:29          1.203674
# 2            00:13:14          3.540392
# 3            00:08:46          1.203674
# 4            00:15:19          1.203674
# ...               ...               ...
# 4331702      00:02:13          0.599906
# 4331703      00:03:35          0.599737
# 4331704      00:03:50          0.599737
# 4331705      00:17:38          1.937855
# 4331706      00:03:38          0.599737
#
# [4331707 rows x 16 columns]

# %%
cleaned_df.describe()
# Out:
#           start_lat     start_lng       end_lat       end_lng  \
# count  4.331707e+06  4.331707e+06  4.331707e+06  4.331707e+06
# mean   4.190095e+01 -8.764466e+01  4.190137e+01 -8.764487e+01
# std    4.301374e-02  2.490093e-02  5.549544e-02  7.712000e-02
# min    4.164850e+01 -8.784409e+01  0.000000e+00 -8.784406e+01
# 25%    4.188090e+01 -8.765766e+01  4.188096e+01 -8.765842e+01
# 50%    4.189636e+01 -8.764170e+01  4.189662e+01 -8.764182e+01
# 75%    4.192677e+01 -8.762858e+01  4.192877e+01 -8.762858e+01
# max    4.206487e+01 -8.752823e+01  4.206485e+01  0.000000e+00
#
#        ride_duration_seconds  ride_distance_km
# count           4.331707e+06      4.331707e+06
# mean            9.571109e+02      2.064642e+00
# std             2.165232e+03      8.373893e+00
# min            -3.274000e+03      0.000000e+00
# 25%             3.370000e+02      8.653234e-01
# 50%             5.880000e+02      1.521886e+00
# 75%             1.049000e+03      2.674941e+00
# max             7.281780e+05      9.818680e+03

# %% [markdown]
# We can see that there might be some incorrect data as the min of the ride_duration_seconds is in minus

# %%
# We will identify if there are any ride that have a minus duration
negative_duration = (cleaned_df[cleaned_df['ride_duration_seconds'] < 0])
negative_duration
# Out:
#                   ride_id  rideable_type          started_at  \
# 764803   7A4D237E2C99D424  electric_bike 2023-04-04 17:15:08
# 764819   81E1C5175FA5A23D   classic_bike 2023-04-19 14:47:18
# 764899   0063C3704F56EC55  electric_bike 2023-04-27 07:51:14
# 828843   934174DB8E2AD791   classic_bike 2023-05-29 17:34:21
# 1000114  00AC4040E25E347E   classic_bike 2023-05-07 15:54:58
# ...                   ...            ...                 ...
# 4154958  83192DD2002545D0   classic_bike 2023-11-05 01:59:44
# 4180062  7C0E4814223D9710  electric_bike 2023-12-07 22:20:28
# 4186483  C8877899E19F9ECE   classic_bike 2023-12-27 13:39:26
# 4212971  DCA596368AD72625  electric_bike 2023-12-05 17:12:57
# 4221041  0129ED570EF2C20E   classic_bike 2023-12-11 19:31:28
#
#                    ended_at               start_station_name start_station_id  \
# 764803  2023-04-04 17:15:05          Green St & Randolph St*     chargingstx3
# 764819  2023-04-19 14:47:14          Green St & Randolph St*     chargingstx3
# 764899  2023-04-27 07:51:09          Green St & Randolph St*     chargingstx3
# 828843  2023-05-29 17:34:09  Lakefront Trail & Bryn Mawr Ave            15576
# 1000114 2023-05-07 15:54:47       Wentworth Ave & Cermak Rd*    chargingstx07
# ...                     ...                              ...              ...
# 4154958 2023-11-05 01:12:56             Racine Ave & 13th St            13165
# 4180062 2023-12-07 22:05:49       Clifton Ave & Armitage Ave     TA1307000163
# 4186483 2023-12-27 13:39:25           State St & Chicago Ave            21544
# 4212971 2023-12-05 17:12:45         Elston Ave & Cortland St     TA1305000039
# 4221041 2023-12-11 19:31:27         Loomis St & Lexington St            13332
#
#                          end_station_name end_station_id  start_lat  \
# 764803            Green St & Randolph St*   chargingstx3  41.883615
# 764819            Green St & Randolph St*   chargingstx3  41.883602
# 764899            Green St & Randolph St*   chargingstx3  41.883460
# 828843    Lakefront Trail & Bryn Mawr Ave          15576  41.984044
# 1000114        Wentworth Ave & Cermak Rd*  chargingstx07  41.853214
# ...                                   ...            ...        ...
# 4154958             Emerald Ave & 31st St   TA1309000055  41.865054
# 4180062  W Armitage Ave & N Sheffield Ave        20254.0  41.918226
# 4186483            State St & Chicago Ave          21544  41.896617
# 4212971          Elston Ave & Cortland St   TA1305000039  41.916456
# 4221041          Loomis St & Lexington St          13332  41.872229
#
#          start_lng    end_lat    end_lng member_casual  ride_duration_seconds  \
# 764803  -87.648556  41.883602 -87.648627        member                   -3.0
# 764819  -87.648627  41.883602 -87.648627        member                   -4.0
# 764899  -87.648600  41.883602 -87.648627        casual                   -5.0
# 828843  -87.652281  41.984044 -87.652281        member                  -12.0
# 1000114 -87.631872  41.853214 -87.631872        casual                  -11.0
# ...            ...        ...        ...           ...                    ...
# 4154958 -87.656959  41.838198 -87.645143        casual                -2808.0
# 4180062 -87.656975  41.917805 -87.653449        member                 -879.0
# 4186483 -87.628579  41.896617 -87.628579        member                   -1.0
# 4212971 -87.666810  41.916433 -87.666746        member                  -12.0
# 4221041 -87.661364  41.872229 -87.661364        member                   -1.0
#
#         ride_duration  ride_distance_km
# 764803       -1:59:57          0.006067
# 764819       -1:59:56          0.000000
# 764899       -1:59:55          0.015831
# 828843       -1:59:48          0.000000
# 1000114      -1:59:49          0.000000
# ...               ...               ...
# 4154958      -1:13:12          3.140152
# 4180062      -1:45:21          0.296199
# 4186483      -1:59:59          0.000000
# 4212971      -1:59:48          0.005818
# 4221041      -1:59:59          0.000000
#
# [66 rows x 16 columns]

# %% [markdown]
# We can see that some observation might be incorrectly input as they are ending the ride before the starting of the ride

# %%
# We will drop all the rows that have minus duration
cleaned_df = cleaned_df[cleaned_df['ride_duration_seconds'] >= 0].copy()
cleaned_df.describe()
# Out:
#           start_lat     start_lng       end_lat       end_lng  \
# count  4.331641e+06  4.331641e+06  4.331641e+06  4.331641e+06
# mean   4.190095e+01 -8.764466e+01  4.190137e+01 -8.764487e+01
# std    4.301377e-02  2.490089e-02  5.549559e-02  7.712052e-02
# min    4.164850e+01 -8.784409e+01  0.000000e+00 -8.784406e+01
# 25%    4.188090e+01 -8.765766e+01  4.188096e+01 -8.765842e+01
# 50%    4.189636e+01 -8.764170e+01  4.189662e+01 -8.764182e+01
# 75%    4.192677e+01 -8.762858e+01  4.192877e+01 -8.762858e+01
# max    4.206487e+01 -8.752823e+01  4.206485e+01  0.000000e+00
#
#        ride_duration_seconds  ride_distance_km
# count           4.331641e+06      4.331641e+06
# mean            9.571449e+02      2.064656e+00
# std             2.165224e+03      8.373953e+00
# min             0.000000e+00      0.000000e+00
# 25%             3.370000e+02      8.653234e-01
# 50%             5.880000e+02      1.521886e+00
# 75%             1.049000e+03      2.674941e+00
# max             7.281780e+05      9.818680e+03

# %%
cleaned_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike 2023-01-12 13:58:01
# ...                   ...            ...                 ...
# 4331702  F74DF9549B504A6B  electric_bike 2023-12-07 13:15:24
# 4331703  BCDA66E761CC1029   classic_bike 2023-12-08 18:42:21
# 4331704  D2CF330F9C266683   classic_bike 2023-12-05 14:09:11
# 4331705  3829A0D1E00EE970  electric_bike 2023-12-02 21:36:07
# 4331706  A373F5B447AEA508   classic_bike 2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2       2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3       2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4       2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                     ...                          ...              ...
# 4331702 2023-12-07 13:17:37            900 W Harrison St            13028
# 4331703 2023-12-08 18:45:56            900 W Harrison St            13028
# 4331704 2023-12-05 14:13:01            900 W Harrison St            13028
# 4331705 2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4331706 2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4331702      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4331703      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331704      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331705            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4331706      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual  ride_duration_seconds  \
# 0        41.930000 -87.640000        member                  651.0
# 1        41.809835 -87.599383        member                  509.0
# 2        42.039742 -87.699413        casual                  794.0
# 3        41.809835 -87.599383        member                  526.0
# 4        41.809835 -87.599383        member                  919.0
# ...            ...        ...           ...                    ...
# 4331702  41.874640 -87.657030        casual                  133.0
# 4331703  41.874640 -87.657030        casual                  215.0
# 4331704  41.874640 -87.657030        member                  230.0
# 4331705  41.885492 -87.652289        casual                 1058.0
# 4331706  41.874640 -87.657030        member                  218.0
#
#         ride_duration  ride_distance_km
# 0            00:10:51          0.839313
# 1            00:08:29          1.203674
# 2            00:13:14          3.540392
# 3            00:08:46          1.203674
# 4            00:15:19          1.203674
# ...               ...               ...
# 4331702      00:02:13          0.599906
# 4331703      00:03:35          0.599737
# 4331704      00:03:50          0.599737
# 4331705      00:17:38          1.937855
# 4331706      00:03:38          0.599737
#
# [4331641 rows x 16 columns]

# %% [markdown]
# There are 4331641 rows left after we romoved 66 rows that have minus duration

# %%
# We will inspect the rides that are having the ride distance as 0
zero_distance = (cleaned_df[cleaned_df['ride_distance_km'] == 0])
zero_distance
# Out:
#                   ride_id  rideable_type          started_at  \
# 39       C1D80BC2F7A0AF30  electric_bike 2023-01-19 19:17:46
# 40       B4ED20B291AB768F  electric_bike 2023-01-26 12:36:49
# 56       D9012A259FE14AC9   classic_bike 2023-01-19 17:42:02
# 57       BD8BFC9CDEA07766  electric_bike 2023-01-02 13:49:25
# 58       6BB8F0DF56396D42  electric_bike 2023-01-17 07:48:48
# ...                   ...            ...                 ...
# 4328962  4517D7CDF82AC58E   classic_bike 2023-12-10 16:22:23
# 4328963  9318BCD0E9623AE4   classic_bike 2023-12-09 13:35:27
# 4328966  A8C04F6E06E8A6FD   classic_bike 2023-12-27 12:44:15
# 4329307  569CDC2AC738CDB0   classic_bike 2023-12-16 19:26:50
# 4329370  87A05A994DC30571   classic_bike 2023-12-08 16:10:38
#
#                    ended_at               start_station_name start_station_id  \
# 39      2023-01-19 19:18:14        Hampden Ct & Diversey Ave         202480.0
# 40      2023-01-26 12:37:37        Hampden Ct & Diversey Ave         202480.0
# 56      2023-01-19 17:42:06  Sacramento Blvd & Franklin Blvd     KA1504000113
# 57      2023-01-02 13:49:41        Hampden Ct & Diversey Ave         202480.0
# 58      2023-01-17 07:49:00             Pulaski Rd & 51st St              343
# ...                     ...                              ...              ...
# 4328962 2023-12-10 16:22:25           Clark St & Lincoln Ave            13179
# 4328963 2023-12-09 13:47:04         Fairbanks Ct & Grand Ave     TA1305000003
# 4328966 2023-12-27 12:47:27         Fairbanks Ct & Grand Ave     TA1305000003
# 4329307 2023-12-16 19:28:22         Fairbanks Ct & Grand Ave     TA1305000003
# 4329370 2023-12-08 16:54:11           Michigan Ave & 14th St     TA1307000124
#
#                         end_station_name end_station_id  start_lat  start_lng  \
# 39             Hampden Ct & Diversey Ave       202480.0  41.930000 -87.640000
# 40             Hampden Ct & Diversey Ave       202480.0  41.930000 -87.640000
# 56       Sacramento Blvd & Franklin Blvd   KA1504000113  41.890469 -87.702608
# 57             Hampden Ct & Diversey Ave       202480.0  41.930000 -87.640000
# 58                  Pulaski Rd & 51st St            343  41.800000 -87.720000
# ...                                  ...            ...        ...        ...
# 4328962           Clark St & Lincoln Ave          13179  41.915689 -87.634600
# 4328963         Fairbanks Ct & Grand Ave   TA1305000003  41.891847 -87.620580
# 4328966         Fairbanks Ct & Grand Ave   TA1305000003  41.891847 -87.620580
# 4329307         Fairbanks Ct & Grand Ave   TA1305000003  41.891847 -87.620580
# 4329370           Michigan Ave & 14th St   TA1307000124  41.864059 -87.623727
#
#            end_lat    end_lng member_casual  ride_duration_seconds  \
# 39       41.930000 -87.640000        casual                   28.0
# 40       41.930000 -87.640000        member                   48.0
# 56       41.890469 -87.702608        member                    4.0
# 57       41.930000 -87.640000        casual                   16.0
# 58       41.800000 -87.720000        casual                   12.0
# ...            ...        ...           ...                    ...
# 4328962  41.915689 -87.634600        member                    2.0
# 4328963  41.891847 -87.620580        member                  697.0
# 4328966  41.891847 -87.620580        member                  192.0
# 4329307  41.891847 -87.620580        member                   92.0
# 4329370  41.864059 -87.623727        member                 2613.0
#
#         ride_duration  ride_distance_km
# 39           00:00:28               0.0
# 40           00:00:48               0.0
# 56           00:00:04               0.0
# 57           00:00:16               0.0
# 58           00:00:12               0.0
# ...               ...               ...
# 4328962      00:00:02               0.0
# 4328963      00:11:37               0.0
# 4328966      00:03:12               0.0
# 4329307      00:01:32               0.0
# 4329370      00:43:33               0.0
#
# [179849 rows x 16 columns]

# %% [markdown]
# These rides are most likely to be a round trip as they all have the same start and ending station which make the distance of the ride equal to zero

# %%
# Next, we will create a column to identify whether the ride is a one-way or round trip
def trip_type(row):
    if row['ride_distance_km'] == 0:
        return "Round trip"
    else:
        return "One-way trip"

cleaned_df['ride_type'] = cleaned_df.apply(trip_type, axis = 1)

# %%
cleaned_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike 2023-01-12 13:58:01
# ...                   ...            ...                 ...
# 4331702  F74DF9549B504A6B  electric_bike 2023-12-07 13:15:24
# 4331703  BCDA66E761CC1029   classic_bike 2023-12-08 18:42:21
# 4331704  D2CF330F9C266683   classic_bike 2023-12-05 14:09:11
# 4331705  3829A0D1E00EE970  electric_bike 2023-12-02 21:36:07
# 4331706  A373F5B447AEA508   classic_bike 2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2       2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3       2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4       2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                     ...                          ...              ...
# 4331702 2023-12-07 13:17:37            900 W Harrison St            13028
# 4331703 2023-12-08 18:45:56            900 W Harrison St            13028
# 4331704 2023-12-05 14:13:01            900 W Harrison St            13028
# 4331705 2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4331706 2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4331702      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4331703      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331704      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331705            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4331706      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual  ride_duration_seconds  \
# 0        41.930000 -87.640000        member                  651.0
# 1        41.809835 -87.599383        member                  509.0
# 2        42.039742 -87.699413        casual                  794.0
# 3        41.809835 -87.599383        member                  526.0
# 4        41.809835 -87.599383        member                  919.0
# ...            ...        ...           ...                    ...
# 4331702  41.874640 -87.657030        casual                  133.0
# 4331703  41.874640 -87.657030        casual                  215.0
# 4331704  41.874640 -87.657030        member                  230.0
# 4331705  41.885492 -87.652289        casual                 1058.0
# 4331706  41.874640 -87.657030        member                  218.0
#
#         ride_duration  ride_distance_km     ride_type
# 0            00:10:51          0.839313  One-way trip
# 1            00:08:29          1.203674  One-way trip
# 2            00:13:14          3.540392  One-way trip
# 3            00:08:46          1.203674  One-way trip
# 4            00:15:19          1.203674  One-way trip
# ...               ...               ...           ...
# 4331702      00:02:13          0.599906  One-way trip
# 4331703      00:03:35          0.599737  One-way trip
# 4331704      00:03:50          0.599737  One-way trip
# 4331705      00:17:38          1.937855  One-way trip
# 4331706      00:03:38          0.599737  One-way trip
#
# [4331641 rows x 17 columns]

# %% [markdown]
# Next, we will create a column called day_of_week and month to stored the day of the week and month of each ride, respectively.

# %%
cleaned_df['day_of_week'] = cleaned_df['started_at'].dt.day_name()
cleaned_df['month'] = cleaned_df['started_at'].dt.month_name()
cleaned_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike 2023-01-12 13:58:01
# ...                   ...            ...                 ...
# 4331702  F74DF9549B504A6B  electric_bike 2023-12-07 13:15:24
# 4331703  BCDA66E761CC1029   classic_bike 2023-12-08 18:42:21
# 4331704  D2CF330F9C266683   classic_bike 2023-12-05 14:09:11
# 4331705  3829A0D1E00EE970  electric_bike 2023-12-02 21:36:07
# 4331706  A373F5B447AEA508   classic_bike 2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2       2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3       2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4       2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                     ...                          ...              ...
# 4331702 2023-12-07 13:17:37            900 W Harrison St            13028
# 4331703 2023-12-08 18:45:56            900 W Harrison St            13028
# 4331704 2023-12-05 14:13:01            900 W Harrison St            13028
# 4331705 2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4331706 2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4331702      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4331703      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331704      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331705            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4331706      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual  ride_duration_seconds  \
# 0        41.930000 -87.640000        member                  651.0
# 1        41.809835 -87.599383        member                  509.0
# 2        42.039742 -87.699413        casual                  794.0
# 3        41.809835 -87.599383        member                  526.0
# 4        41.809835 -87.599383        member                  919.0
# ...            ...        ...           ...                    ...
# 4331702  41.874640 -87.657030        casual                  133.0
# 4331703  41.874640 -87.657030        casual                  215.0
# 4331704  41.874640 -87.657030        member                  230.0
# 4331705  41.885492 -87.652289        casual                 1058.0
# 4331706  41.874640 -87.657030        member                  218.0
#
#         ride_duration  ride_distance_km     ride_type day_of_week     month
# 0            00:10:51          0.839313  One-way trip    Saturday   January
# 1            00:08:29          1.203674  One-way trip     Tuesday   January
# 2            00:13:14          3.540392  One-way trip      Monday   January
# 3            00:08:46          1.203674  One-way trip      Sunday   January
# 4            00:15:19          1.203674  One-way trip    Thursday   January
# ...               ...               ...           ...         ...       ...
# 4331702      00:02:13          0.599906  One-way trip    Thursday  December
# 4331703      00:03:35          0.599737  One-way trip      Friday  December
# 4331704      00:03:50          0.599737  One-way trip     Tuesday  December
# 4331705      00:17:38          1.937855  One-way trip    Saturday  December
# 4331706      00:03:38          0.599737  One-way trip      Monday  December
#
# [4331641 rows x 19 columns]

# %% [markdown]
# We will also create a season column by using the month column
#
# (Please note that the underlying data was collected from the US, Chicago to be specific)

# %%
month_to_season = {
    'January': 'Winter', 'February': 'Winter', 'March': 'Spring', 'April': 'Spring',
    'May': 'Spring', 'June': 'Summer', 'July': 'Summer', 'August': 'Summer',
    'September': 'Fall', 'October': 'Fall', 'November': 'Fall', 'December': 'Winter'
}

cleaned_df['season'] = cleaned_df['month'].map(month_to_season)
cleaned_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike 2023-01-12 13:58:01
# ...                   ...            ...                 ...
# 4331702  F74DF9549B504A6B  electric_bike 2023-12-07 13:15:24
# 4331703  BCDA66E761CC1029   classic_bike 2023-12-08 18:42:21
# 4331704  D2CF330F9C266683   classic_bike 2023-12-05 14:09:11
# 4331705  3829A0D1E00EE970  electric_bike 2023-12-02 21:36:07
# 4331706  A373F5B447AEA508   classic_bike 2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2       2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3       2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4       2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                     ...                          ...              ...
# 4331702 2023-12-07 13:17:37            900 W Harrison St            13028
# 4331703 2023-12-08 18:45:56            900 W Harrison St            13028
# 4331704 2023-12-05 14:13:01            900 W Harrison St            13028
# 4331705 2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4331706 2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4331702      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4331703      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331704      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331705            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4331706      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual  ride_duration_seconds  \
# 0        41.930000 -87.640000        member                  651.0
# 1        41.809835 -87.599383        member                  509.0
# 2        42.039742 -87.699413        casual                  794.0
# 3        41.809835 -87.599383        member                  526.0
# 4        41.809835 -87.599383        member                  919.0
# ...            ...        ...           ...                    ...
# 4331702  41.874640 -87.657030        casual                  133.0
# 4331703  41.874640 -87.657030        casual                  215.0
# 4331704  41.874640 -87.657030        member                  230.0
# 4331705  41.885492 -87.652289        casual                 1058.0
# 4331706  41.874640 -87.657030        member                  218.0
#
#         ride_duration  ride_distance_km     ride_type day_of_week     month  \
# 0            00:10:51          0.839313  One-way trip    Saturday   January
# 1            00:08:29          1.203674  One-way trip     Tuesday   January
# 2            00:13:14          3.540392  One-way trip      Monday   January
# 3            00:08:46          1.203674  One-way trip      Sunday   January
# 4            00:15:19          1.203674  One-way trip    Thursday   January
# ...               ...               ...           ...         ...       ...
# 4331702      00:02:13          0.599906  One-way trip    Thursday  December
# 4331703      00:03:35          0.599737  One-way trip      Friday  December
# 4331704      00:03:50          0.599737  One-way trip     Tuesday  December
# 4331705      00:17:38          1.937855  One-way trip    Saturday  December
# 4331706      00:03:38          0.599737  One-way trip      Monday  December
#
#          season
# 0        Winter
# 1        Winter
# 2        Winter
# 3        Winter
# 4        Winter
# ...         ...
# 4331702  Winter
# 4331703  Winter
# 4331704  Winter
# 4331705  Winter
# 4331706  Winter
#
# [4331641 rows x 20 columns]

# %% [markdown]
# We will also create a start hour column then use it to categorized each ride into part of the days.

# %%
# Extract hour from 'started_at'
cleaned_df['start_hour'] = cleaned_df['started_at'].dt.hour

# Categorized each rides into part of the days
def categorize_time(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'

cleaned_df['part_of_the_day'] = cleaned_df['start_hour'].apply(categorize_time)
cleaned_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        F96D5A74A3E41399  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A   classic_bike 2023-01-12 13:58:01
# ...                   ...            ...                 ...
# 4331702  F74DF9549B504A6B  electric_bike 2023-12-07 13:15:24
# 4331703  BCDA66E761CC1029   classic_bike 2023-12-08 18:42:21
# 4331704  D2CF330F9C266683   classic_bike 2023-12-05 14:09:11
# 4331705  3829A0D1E00EE970  electric_bike 2023-12-02 21:36:07
# 4331706  A373F5B447AEA508   classic_bike 2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# 2       2023-01-02 08:05:11       Western Ave & Lunt Ave           RP-005
# 3       2023-01-22 11:01:44        Kimbark Ave & 53rd St     TA1309000037
# 4       2023-01-12 14:13:20        Kimbark Ave & 53rd St     TA1309000037
# ...                     ...                          ...              ...
# 4331702 2023-12-07 13:17:37            900 W Harrison St            13028
# 4331703 2023-12-08 18:45:56            900 W Harrison St            13028
# 4331704 2023-12-05 14:13:01            900 W Harrison St            13028
# 4331705 2023-12-02 21:53:45       Damen Ave & Madison St            13134
# 4331706 2023-12-11 13:11:24            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4331702      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4331703      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331704      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331705            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4331706      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng member_casual  ride_duration_seconds  \
# 0        41.930000 -87.640000        member                  651.0
# 1        41.809835 -87.599383        member                  509.0
# 2        42.039742 -87.699413        casual                  794.0
# 3        41.809835 -87.599383        member                  526.0
# 4        41.809835 -87.599383        member                  919.0
# ...            ...        ...           ...                    ...
# 4331702  41.874640 -87.657030        casual                  133.0
# 4331703  41.874640 -87.657030        casual                  215.0
# 4331704  41.874640 -87.657030        member                  230.0
# 4331705  41.885492 -87.652289        casual                 1058.0
# 4331706  41.874640 -87.657030        member                  218.0
#
#         ride_duration  ride_distance_km     ride_type day_of_week     month  \
# 0            00:10:51          0.839313  One-way trip    Saturday   January
# 1            00:08:29          1.203674  One-way trip     Tuesday   January
# 2            00:13:14          3.540392  One-way trip      Monday   January
# 3            00:08:46          1.203674  One-way trip      Sunday   January
# 4            00:15:19          1.203674  One-way trip    Thursday   January
# ...               ...               ...           ...         ...       ...
# 4331702      00:02:13          0.599906  One-way trip    Thursday  December
# 4331703      00:03:35          0.599737  One-way trip      Friday  December
# 4331704      00:03:50          0.599737  One-way trip     Tuesday  December
# 4331705      00:17:38          1.937855  One-way trip    Saturday  December
# 4331706      00:03:38          0.599737  One-way trip      Monday  December
#
#          season  start_hour part_of_the_day
# 0        Winter          20         Evening
# 1        Winter          15       Afternoon
# 2        Winter           7         Morning
# 3        Winter          10         Morning
# 4        Winter          13       Afternoon
# ...         ...         ...             ...
# 4331702  Winter          13       Afternoon
# 4331703  Winter          18         Evening
# 4331704  Winter          14       Afternoon
# 4331705  Winter          21           Night
# 4331706  Winter          13       Afternoon
#
# [4331641 rows x 22 columns]

# %% [markdown]
# We will rearrange the column to make it more organize

# %%
new_columns = [
    'ride_id', 'member_casual', 'rideable_type', 'started_at', 'ended_at', 'day_of_week', 'month', 'season',
    'start_hour', 'part_of_the_day', 'start_station_name', 'start_station_id', 'end_station_name', 'end_station_id',
    'start_lat', 'start_lng', 'end_lat', 'end_lng', 'ride_duration', 'ride_duration_seconds', 'ride_distance_km', 
    'ride_type'
]

comp_df = cleaned_df.reindex(columns = new_columns)
comp_df
# Out:
#                   ride_id member_casual  rideable_type          started_at  \
# 0        F96D5A74A3E41399        member  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88        member   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5        casual  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968        member   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A        member   classic_bike 2023-01-12 13:58:01
# ...                   ...           ...            ...                 ...
# 4331702  F74DF9549B504A6B        casual  electric_bike 2023-12-07 13:15:24
# 4331703  BCDA66E761CC1029        casual   classic_bike 2023-12-08 18:42:21
# 4331704  D2CF330F9C266683        member   classic_bike 2023-12-05 14:09:11
# 4331705  3829A0D1E00EE970        casual  electric_bike 2023-12-02 21:36:07
# 4331706  A373F5B447AEA508        member   classic_bike 2023-12-11 13:07:46
#
#                    ended_at day_of_week     month  season  start_hour  \
# 0       2023-01-21 20:16:33    Saturday   January  Winter          20
# 1       2023-01-10 15:46:05     Tuesday   January  Winter          15
# 2       2023-01-02 08:05:11      Monday   January  Winter           7
# 3       2023-01-22 11:01:44      Sunday   January  Winter          10
# 4       2023-01-12 14:13:20    Thursday   January  Winter          13
# ...                     ...         ...       ...     ...         ...
# 4331702 2023-12-07 13:17:37    Thursday  December  Winter          13
# 4331703 2023-12-08 18:45:56      Friday  December  Winter          18
# 4331704 2023-12-05 14:13:01     Tuesday  December  Winter          14
# 4331705 2023-12-02 21:53:45    Saturday  December  Winter          21
# 4331706 2023-12-11 13:11:24      Monday  December  Winter          13
#
#         part_of_the_day           start_station_name start_station_id  \
# 0               Evening  Lincoln Ave & Fullerton Ave     TA1309000058
# 1             Afternoon        Kimbark Ave & 53rd St     TA1309000037
# 2               Morning       Western Ave & Lunt Ave           RP-005
# 3               Morning        Kimbark Ave & 53rd St     TA1309000037
# 4             Afternoon        Kimbark Ave & 53rd St     TA1309000037
# ...                 ...                          ...              ...
# 4331702       Afternoon            900 W Harrison St            13028
# 4331703         Evening            900 W Harrison St            13028
# 4331704       Afternoon            900 W Harrison St            13028
# 4331705           Night       Damen Ave & Madison St            13134
# 4331706       Afternoon            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4331702      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4331703      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331704      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331705            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4331706      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng ride_duration  ride_duration_seconds  \
# 0        41.930000 -87.640000      00:10:51                  651.0
# 1        41.809835 -87.599383      00:08:29                  509.0
# 2        42.039742 -87.699413      00:13:14                  794.0
# 3        41.809835 -87.599383      00:08:46                  526.0
# 4        41.809835 -87.599383      00:15:19                  919.0
# ...            ...        ...           ...                    ...
# 4331702  41.874640 -87.657030      00:02:13                  133.0
# 4331703  41.874640 -87.657030      00:03:35                  215.0
# 4331704  41.874640 -87.657030      00:03:50                  230.0
# 4331705  41.885492 -87.652289      00:17:38                 1058.0
# 4331706  41.874640 -87.657030      00:03:38                  218.0
#
#          ride_distance_km     ride_type
# 0                0.839313  One-way trip
# 1                1.203674  One-way trip
# 2                3.540392  One-way trip
# 3                1.203674  One-way trip
# 4                1.203674  One-way trip
# ...                   ...           ...
# 4331702          0.599906  One-way trip
# 4331703          0.599737  One-way trip
# 4331704          0.599737  One-way trip
# 4331705          1.937855  One-way trip
# 4331706          0.599737  One-way trip
#
# [4331641 rows x 22 columns]

# %%
comp_df = comp_df.rename(columns={'member_casual': 'user_type'})
comp_df
# Out:
#                   ride_id user_type  rideable_type          started_at  \
# 0        F96D5A74A3E41399    member  electric_bike 2023-01-21 20:05:42
# 1        13CB7EB698CEDB88    member   classic_bike 2023-01-10 15:37:36
# 2        BD88A2E670661CE5    casual  electric_bike 2023-01-02 07:51:57
# 3        C90792D034FED968    member   classic_bike 2023-01-22 10:52:58
# 4        3397017529188E8A    member   classic_bike 2023-01-12 13:58:01
# ...                   ...       ...            ...                 ...
# 4331702  F74DF9549B504A6B    casual  electric_bike 2023-12-07 13:15:24
# 4331703  BCDA66E761CC1029    casual   classic_bike 2023-12-08 18:42:21
# 4331704  D2CF330F9C266683    member   classic_bike 2023-12-05 14:09:11
# 4331705  3829A0D1E00EE970    casual  electric_bike 2023-12-02 21:36:07
# 4331706  A373F5B447AEA508    member   classic_bike 2023-12-11 13:07:46
#
#                    ended_at day_of_week     month  season  start_hour  \
# 0       2023-01-21 20:16:33    Saturday   January  Winter          20
# 1       2023-01-10 15:46:05     Tuesday   January  Winter          15
# 2       2023-01-02 08:05:11      Monday   January  Winter           7
# 3       2023-01-22 11:01:44      Sunday   January  Winter          10
# 4       2023-01-12 14:13:20    Thursday   January  Winter          13
# ...                     ...         ...       ...     ...         ...
# 4331702 2023-12-07 13:17:37    Thursday  December  Winter          13
# 4331703 2023-12-08 18:45:56      Friday  December  Winter          18
# 4331704 2023-12-05 14:13:01     Tuesday  December  Winter          14
# 4331705 2023-12-02 21:53:45    Saturday  December  Winter          21
# 4331706 2023-12-11 13:11:24      Monday  December  Winter          13
#
#         part_of_the_day           start_station_name start_station_id  \
# 0               Evening  Lincoln Ave & Fullerton Ave     TA1309000058
# 1             Afternoon        Kimbark Ave & 53rd St     TA1309000037
# 2               Morning       Western Ave & Lunt Ave           RP-005
# 3               Morning        Kimbark Ave & 53rd St     TA1309000037
# 4             Afternoon        Kimbark Ave & 53rd St     TA1309000037
# ...                 ...                          ...              ...
# 4331702       Afternoon            900 W Harrison St            13028
# 4331703         Evening            900 W Harrison St            13028
# 4331704       Afternoon            900 W Harrison St            13028
# 4331705           Night       Damen Ave & Madison St            13134
# 4331706       Afternoon            900 W Harrison St            13028
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0             Hampden Ct & Diversey Ave       202480.0  41.924074 -87.646278
# 1               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 2        Valli Produce - Evanston Plaza            599  42.008571 -87.690483
# 3               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# 4               Greenwood Ave & 47th St   TA1308000002  41.799568 -87.594747
# ...                                 ...            ...        ...        ...
# 4331702      Racine Ave & Congress Pkwy   TA1306000025  41.874702 -87.649804
# 4331703      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331704      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
# 4331705            Morgan St & Lake St*   chargingstx4  41.881396 -87.674984
# 4331706      Racine Ave & Congress Pkwy   TA1306000025  41.874754 -87.649807
#
#            end_lat    end_lng ride_duration  ride_duration_seconds  \
# 0        41.930000 -87.640000      00:10:51                  651.0
# 1        41.809835 -87.599383      00:08:29                  509.0
# 2        42.039742 -87.699413      00:13:14                  794.0
# 3        41.809835 -87.599383      00:08:46                  526.0
# 4        41.809835 -87.599383      00:15:19                  919.0
# ...            ...        ...           ...                    ...
# 4331702  41.874640 -87.657030      00:02:13                  133.0
# 4331703  41.874640 -87.657030      00:03:35                  215.0
# 4331704  41.874640 -87.657030      00:03:50                  230.0
# 4331705  41.885492 -87.652289      00:17:38                 1058.0
# 4331706  41.874640 -87.657030      00:03:38                  218.0
#
#          ride_distance_km     ride_type
# 0                0.839313  One-way trip
# 1                1.203674  One-way trip
# 2                3.540392  One-way trip
# 3                1.203674  One-way trip
# 4                1.203674  One-way trip
# ...                   ...           ...
# 4331702          0.599906  One-way trip
# 4331703          0.599737  One-way trip
# 4331704          0.599737  One-way trip
# 4331705          1.937855  One-way trip
# 4331706          0.599737  One-way trip
#
# [4331641 rows x 22 columns]

# %% [markdown]
# ## Analyze

# %%
comp_df.describe()
# Out:
#          start_hour     start_lat     start_lng       end_lat       end_lng  \
# count  4.331641e+06  4.331641e+06  4.331641e+06  4.331641e+06  4.331641e+06
# mean   1.405611e+01  4.190095e+01 -8.764466e+01  4.190137e+01 -8.764487e+01
# std    4.862318e+00  4.301377e-02  2.490089e-02  5.549559e-02  7.712052e-02
# min    0.000000e+00  4.164850e+01 -8.784409e+01  0.000000e+00 -8.784406e+01
# 25%    1.100000e+01  4.188090e+01 -8.765766e+01  4.188096e+01 -8.765842e+01
# 50%    1.500000e+01  4.189636e+01 -8.764170e+01  4.189662e+01 -8.764182e+01
# 75%    1.800000e+01  4.192677e+01 -8.762858e+01  4.192877e+01 -8.762858e+01
# max    2.300000e+01  4.206487e+01 -8.752823e+01  4.206485e+01  0.000000e+00
#
#        ride_duration_seconds  ride_distance_km
# count           4.331641e+06      4.331641e+06
# mean            9.571449e+02      2.064656e+00
# std             2.165224e+03      8.373953e+00
# min             0.000000e+00      0.000000e+00
# 25%             3.370000e+02      8.653234e-01
# 50%             5.880000e+02      1.521886e+00
# 75%             1.049000e+03      2.674941e+00
# max             7.281780e+05      9.818680e+03

# %%
# We will calculate the amount of ride by each type of member
member_casual_counts = comp_df['user_type'].value_counts()
member_casual_counts
# Out:
# member    2799920
# casual    1531721
# Name: user_type, dtype: int64

# %%
# We will calculate the amount of ride by each type of member as a percentage
member_casual_percentage = (((comp_df['user_type'].value_counts())/len(comp_df))*100).round(2)
member_casual_percentage.columns = ['user_type', 'percentage']
member_casual_percentage
# Out:
# member    64.64
# casual    35.36
# Name: user_type, dtype: float64

# %% [markdown]
# There are a total of 4,331,641 ride in this data.
#
# 2,799,920 of them are member user and 1,531,721 rides are casual user which is equivalent to 64.64% and 35.36%, respectively.

# %%
plt.figure(figsize=(7, 5))
plt.pie(member_casual_percentage, labels=member_casual_percentage, colors=['steelblue', 'olive'])
plt.legend(['member', 'casual'])
plt.show()

# %%
plt.figure(figsize=(7, 5))
plt.bar(member_casual_counts.index, member_casual_counts, color=['steelblue', 'olive'])
plt.title('Amount of Member vs Casual Riders')
plt.xlabel('User Type')
plt.ylabel('Amount')
plt.show()

# %%
# We will calculate the amount of ride by each type of bike
bike_type = comp_df['rideable_type'].value_counts()
bike_type
# Out:
# classic_bike     2690707
# electric_bike    1564810
# docked_bike        76124
# Name: rideable_type, dtype: int64

# %%
plt.figure(figsize=(7, 5))
plt.bar(bike_type.index, bike_type, color=['cornflowerblue', 'indianred', 'lightgray'])
plt.title('Amount of ride by each type of bike')
plt.xlabel('Type of bike')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# There are three types of bikes: classic, electric, and docked. Generally, user prefer to use classic bike.

# %%
# We will see if there are any preference for the type of bike by each type of user 
bike_preferences = comp_df.groupby(['user_type', 'rideable_type']).size().unstack().fillna(0)
bike_preferences
# Out:
# rideable_type  classic_bike  docked_bike  electric_bike
# user_type
# casual             873005.0      76124.0       582592.0
# member            1817702.0          0.0       982218.0

# %%
bike_preferences.plot(kind='bar', figsize=(8, 6), color=['cornflowerblue', 'olive', 'lightgray'])
plt.title('Bike Preferences by Member Type')
plt.xlabel('Member Type')
plt.ylabel('Count of Rides')
plt.legend(title='Rideable Type')
plt.show()

# %% [markdown]
# We can see from the data that casual users prefer to use classic bikes, electric bikes, and docked bikes, respectively. In contrast, member users prefer only classic and electric bikes, with classic bikes being the most preferred.

# %%
# Next, we will calculate the proportion of the ride type between member and casual users
ride_type_counts = comp_df.groupby(['user_type', 'ride_type']).size().unstack()
ride_type_counts
# Out:
# ride_type  One-way trip  Round trip
# user_type
# casual          1428157      103564
# member          2723635       76285

# %% [markdown]
# We can see from the data that both types of users primarily use the bikes for one-way trips. However, casual riders use the bikes for round trips more often than member riders.

# %%
ride_type_counts.plot(kind='bar', stacked=True, figsize=(9, 6), color=['steelblue', 'olive'])
plt.title('Bike Preferences by Member Type')
plt.xlabel('Member Type')
plt.ylabel('Count of Rides')
plt.xticks(rotation=0)
plt.legend(title='Rideable Type')
plt.show()

# %%
#Calculate average ride distance for each type of member by using ride_distance_km
avg_ride_distance = comp_df.groupby('user_type')['ride_distance_km'].mean()
avg_ride_distance
# Out:
# user_type
# casual    2.113848
# member    2.037745
# Name: ride_distance_km, dtype: float64

# %%
# Calculate the average ride duration for each type of member by using ride_duration_seconds and format it into minutes
avg_ride_duration = comp_df.groupby('user_type')['ride_duration_seconds'].mean()
avg_ride_duration = avg_ride_duration/60
avg_ride_duration
# Out:
# user_type
# casual    22.937337
# member    12.131253
# Name: ride_duration_seconds, dtype: float64

# %% [markdown]
# The data shows that member users travel shorter distances and for shorter durations on average than casual users.

# %%
# Next, we are going to calculate the amount of ride in each season and month
ride_by_season = comp_df.groupby(['season','month']).size().reset_index(name='ride_count')

# Calculate the total ride of each season and concat
sum_by_season = ride_by_season.groupby('season')['ride_count'].sum().reset_index()
sum_by_season['month'] = 'Total'
ride_by_season = pd.concat([ride_by_season, sum_by_season], ignore_index=True)
ride_by_season = ride_by_season.sort_values(['season', 'month'])
ride_by_season.set_index(['season', 'month'], inplace=True)
ride_by_season
# Out:
#                   ride_count
# season month
# Fall   November       274766
#        October        403775
#        September      506632
#        Total         1185173
# Spring April          324194
#        March          200447
#        May            463222
#        Total          987863
# Summer August         584912
#        July           573955
#        June           534755
#        Total         1693622
# Winter December       167139
#        February       149560
#        January        148284
#        Total          464983

# %% [markdown]
# The highest amount of rides occurs in the summer, with August having the highest number of rides both within the season and compared to any other month. While winter have the lowest amount of rides.

# %%
# We will calculate the ride in each day of week and also determine whether it's weekday or weekend
def classify_day(day):
    if day in ['Saturday', 'Sunday']:
        return 'Weekend'
    else:
        return 'Weekday'
    
rides_by_day = comp_df.groupby('day_of_week').size().reset_index(name='ride_count')
rides_by_day['day_type'] = rides_by_day['day_of_week'].apply(classify_day)

# We will also calculate the total of each type of day and then concat it to the bottom row of each type of day
sum_by_day_type = rides_by_day.groupby('day_type')['ride_count'].sum().reset_index()
sum_by_day_type['day_of_week'] = 'Total'
rides_by_day = pd.concat([rides_by_day, sum_by_day_type], ignore_index = True)

# Arrange the day into the correct order
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
rides_by_day['day_of_week'] = pd.Categorical(rides_by_day['day_of_week'], categories = day_order + ['Total'], ordered = True)
rides_by_day = rides_by_day.sort_values(['day_type', 'day_of_week'])
rides_by_day.set_index(['day_type', 'day_of_week'], inplace = True)
rides_by_day
# Out:
#                       ride_count
# day_type day_of_week
# Weekday  Monday           562095
#          Tuesday          630384
#          Wednesday        635808
#          Thursday         651583
#          Friday           628372
#          Total           3108242
# Weekend  Saturday         660802
#          Sunday           562597
#          Total           1223399

# %% [markdown]
# Generally, users ride more on weekdays than on weekends. The highest number of rides on a weekday is on Wednesday, while on a weekend it is on Saturday.

# %%
# Calculate the amount of ride in each part of the day
ride_in_part_of_day = comp_df.groupby('part_of_the_day').size().reset_index(name='ride_count')
part_of_day_order = ['Morning', 'Afternoon', 'Evening', 'Night']
ride_in_part_of_day['part_of_the_day'] = pd.Categorical(ride_in_part_of_day['part_of_the_day'], categories=part_of_day_order, ordered=True)
ride_in_part_of_day = ride_in_part_of_day.sort_values('part_of_the_day')
ride_in_part_of_day.set_index(['part_of_the_day', 'ride_count'], inplace = True)
ride_in_part_of_day
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Morning, 1167310), (Afternoon, 1475538), (Evening, 1251331), (Night, 437462)]

# %% [markdown]
# The highest number of rides occurs in the afternoon, while the lowest is at night.

# %% [markdown]
# #

# %% [markdown]
# We will extract the data as a CSV file so we can use it to perform further analysis (if needed) and for the share phrase in Tableau.

# %%
comp_df.to_csv(r'C:\Users\USER\Data\2023-divvy-tripdata\\processed_tripdata.csv', index=False)
